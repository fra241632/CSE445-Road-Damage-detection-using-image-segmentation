# %%
import torch

print(torch.cuda.is_available())

# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
import os

project_path = "/content/drive/MyDrive/Road_Damage_Project"

os.makedirs(project_path, exist_ok=True)

print("Project folder created!")

# %%
# !pip install ultralytics
# !pip install kaggle

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from ultralytics import YOLO

# %%
from ultralytics import YOLO

print("YOLO Installed Successfully!")

# %%
from google.colab import files

uploaded = files.upload()

# %%
# !ls

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !ls ~/.kaggle

# %%
# !kaggle datasets list

# %%
import os

# Define the typical Google Drive mount path
drive_path = '/content/drive/MyDrive'

if os.path.exists(drive_path):
    print("✅ Google Drive is mounted!")
else:
    print("❌ Google Drive is NOT mounted.")

# %%
import os

PROJECT_DIR = "/content/drive/MyDrive/Road_Damage_Project"

folders = [
    "datasets",
    "models",
    "results",
    "runs"
]

for folder in folders:
    os.makedirs(os.path.join(PROJECT_DIR, folder), exist_ok=True)

print("Folders created successfully!")

# %%
# %cd /content/drive/MyDrive/Road_Damage_Project/datasets

# %%
# !kaggle datasets download -d sabidrahman/pothole-cracks-and-openmanhole

# %%
# !ls

# %%
# !unzip -q pothole-cracks-and-openmanhole.zip

# %%
# !find . -maxdepth 2

# %% [markdown]
# Electricity went out. Try again from beginning.

# %%
import torch
print(torch.cuda.is_available())

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls "/content/drive/MyDrive/Road_Damage_Project"

# %%
# !pip install -q ultralytics kaggle

# %%
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list

# %%
# %cd /content/drive/MyDrive/Road_Damage_Project/datasets

# %%
# !kaggle datasets download -d sabidrahman/pothole-cracks-and-openmanhole

# %%
# !ls /content/drive/MyDrive/Road_Damage_Project/

# %%
# !ls

# %%
# !find dataset -maxdepth 3

# %%
# !find dataset -type f | head -20
